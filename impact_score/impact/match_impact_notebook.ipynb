# %%
from match_analysis import RoundReplay
from impact_score.impact.graph_plot import GraphPlotter

rr = RoundReplay()
gp = GraphPlotter()

# %%
match_id = 74033
v_round = 1

rr.set_match(match_id)
gp.set_match(match_id)
rr.choose_round(v_round)
# Out:
# E:\Python\Classification_datascience\venv\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# E:\Python\Classification_datascience\venv\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Round 1 selected
# Round 2 selected
# Round 3 selected
# Round 4 selected
# Round 5 selected
# Round 6 selected
# Round 7 selected
# Round 8 selected
# Round 9 selected
# Round 10 selected
# Round 11 selected
# Round 12 selected
# Round 13 selected
# Round 14 selected
# Round 15 selected
# Round 16 selected
# Round 17 selected
# Round 18 selected
# Round 19 selected
# Round 20 selected
# Round 21 selected
# Round 22 selected
# Round 23 selected
# Round 24 selected
# Round 1 selected

# %%
gp.plot_round(round_number=16, side="def")

# %%
rr.get_clutchy_rounds(chosen_side="def")
# Out:
# {16: '16.71%',
#  19: '33.64%',
#  8: '41.77%',
#  11: '44.48%',
#  7: '46.3%',
#  22: '46.56%',
#  6: '46.84%',
#  1: '49.59%',
#  12: '51.82%',
#  18: '52.86%',
#  15: '53.18%',
#  20: '54.8%',
#  17: '59.72%',
#  9: '76.62%',
#  2: '83.48%'}

# %%
rr.get_player_most_impactful_rounds("Marved")
# Out:
# Round 1 selected
# Round 2 selected
# Round 3 selected
# Round 4 selected
# Round 5 selected
# Round 6 selected
# Round 7 selected
# Round 8 selected
# Round 9 selected
# Round 10 selected
# Round 11 selected
# Round 12 selected
# Round 13 selected
# Round 14 selected
# Round 15 selected
# Round 16 selected
# Round 17 selected
# Round 18 selected
# Round 19 selected
# Round 20 selected
# Round 21 selected
# Round 22 selected
# Round 23 selected
# Round 24 selected
#       Name  Round    Gained      Lost     Delta
# 22  marved     23  1.296459  0.000000  1.296459
# 5   marved      6  0.720288  0.000000  0.720288
# 18  marved     19  0.523786  0.113837  0.409949
# 10  marved     11  0.371913  0.000000  0.371913
# 2   marved      3  0.327967  0.400431 -0.072464
# 23  marved     24  0.280170  0.318295 -0.038125
# 7   marved      8  0.247935  0.227382  0.020553
# 15  marved     16  0.209176  0.276581 -0.067405
# 17  marved     18  0.173682  0.150485  0.023196
# ...

# %%
aux = rr.get_round_probability(side="def", add_events=True)
aux
# Out:
#    Round  EventID EventType  Probability_before_event  \
# 0      1        0     start                  0.569852
# 1      1  7871652      kill                  0.601403
# 2      1  7871653      kill                  0.700896
# 3      1  7871657      kill                  0.820220
# 4      1  7871656      kill                  0.752257
# 5      1  7871654      kill                  0.530324
# 6      1  7871658      kill                  0.763661
# 7      1  7871655      kill                  0.950113
#
#    Probability_after_event    Impact  Killer KillerAgent   Weapon     Ability  \
# 0                 0.569852  0.000000       0           0        0           0
# 1                 0.700896  0.099493  keznit        Jett    Ghost           0
# 2                 0.820220  0.119324  keznit        Jett    Ghost           0
# 3                 0.752257  0.067963  Nivera     Chamber        0  headhunter
# 4                 0.530324  0.221933  Jamppi      Breach  Classic           0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 gp.plot_round(side="atk")
#
# File E:\Python\Classification_datascience\impact_score\impact\graph_plot.py:25, in GraphPlotter.plot_round(self, **kwargs)
#      23 marker_dict = {"atk": "#511C29", "def": "darkblue"}
#      24 round_data = self.rr.get_round_probability(side=chosen_side)
# ---> 25 kills_data_df = pd.DataFrame(export_impact(self.rr.match_id, self.rr.analyser)[f"Round_{round_number}"])
#      26 kills_data_df["RoundTime"] = kills_data_df["timing"] / 1000
#      27 single_stamps = kills_data_df["timing"].tolist()
#
# TypeError: export_impact() missing 1 required positional argument: 'prob_df'

# %%
dd = rr.get_round_impact_dataframe()
dd["Player"] = dd.index
dd
# Out:
#                gained       lost      delta      Player
# BORKUM       0.000000   6.553636  -6.553636      BORKUM
# Chronicle    7.163920   0.804168   6.359751   Chronicle
# d3ffo       33.745904   5.361063  28.384841       d3ffo
# Dispenser    0.000000   7.163920  -7.163920   Dispenser
# DubsteP      0.000000  27.192268 -27.192268     DubsteP
# JessieVash   6.165231   2.615279   3.549952  JessieVash
# nAts         0.000000   0.000000   0.000000        nAts
# Redgar       0.000000   0.000000   0.000000      Redgar
# sheydos     22.098445   0.000000  22.098445     sheydos
# Witz         0.000000  19.483165 -19.483165        Witz

# %%
rr.choose_round(13)

# %%
rr.plot_round(side="def")

# %%
rr.get_round_probability(side="def", add_events=True)
# Out:
#    Round  Round time Stamps  Difference (%)     Actors     Means  Victims  \
# 0    8.0        0.00      A       -0.000000       None      None     None
# 1    8.0       28.77      B       22.755579       NagZ  Operator   Redgar
# 2    8.0       48.87      C      -32.518694       NagZ  Operator  sheydos
# 3    8.0       55.31      D       36.032462  Chronicle    Vandal   keznit
# 4    0.0        0.00      E        0.000000       NagZ  Operator    d3ffo
#
#    Win_probability Final Winner  Integer time
# 0        55.705082          def           0.0
# 1        70.485042          def       28766.0
# 2        37.488501          def       48867.0
# 3        76.262313          def       55312.0
# 4         0.000000            0           0.0

# %%
rr.get_map_impact_dataframe()
# Out:
#         Name    Gain    Lost   Delta  MatchID
# 0   Bonecold  233.60  110.65  122.95    45334
# 1    sheydos  259.57  189.56   70.01    45334
# 2     Redgar  186.98  161.82   25.16    45334
# 3      d3ffo  154.22  143.52   10.70    45334
# 4       zeek  168.16  168.85   -0.69    45334
# 5       cNed  154.20  156.52   -2.32    45334
# 6      kiles  123.07  132.08   -9.01    45334
# 7     Starxo  126.13  185.08  -58.95    45334
# 8       nAts  106.13  177.19  -71.06    45334
# 9  Chronicle   46.28  133.07  -86.79    45334
