# %%
from impact_score.impact.graph_plot import GraphPlotter
import seaborn as sns
from matplotlib import style as mpl_style
from matplotlib import pyplot as plt
from matplotlib import ticker as mpl_ticker
import time

match_id = 60206
gp = GraphPlotter(match_id)
gp.setup_graph_data()
# Out:
# Model path: E:\Python\Classification_datascience\impact_score\model\model.pkl
# Model loading time: 0.007460299999999975
# Round 1 selected
# Round 2 selected
# Round 3 selected
# Round 4 selected
# Round 5 selected
# Round 6 selected
# Round 7 selected
# Round 8 selected
# Round 9 selected
# Round 10 selected
# Round 11 selected
# Round 12 selected
# Round 13 selected
# Round 14 selected
# Round 15 selected
# Round 16 selected
# Round 17 selected
# Round 18 selected
# E:\Python\Classification_datascience\venv\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# E:\Python\Classification_datascience\venv\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
chosen_side = "atk"
color_dict = {"atk": "red", "def": "blue"}
title_dict = {"atk": "Attack", "def": "Defense"}

fig = plt.figure(figsize=(14, 7))
fig.tight_layout()
plt.rcParams.update({'font.size': 13})
# sns.set_context(rc={'patch.linewidth': 2.0})
# sns.set(font_scale=1.3)
# ax = sns.lineplot(data=gp.plot_data, x="Round time", y="Win_probability",ci=None,
#                 linewidth=1, zorder=0, color=color_dict[chosen_side])

plt.plot(gp.plot_data["Round time"], gp.plot_data["Win_probability"], zorder=0, color=color_dict[chosen_side])
ax = plt.gca()
ax.spines["left"].set_position(("data", -4))
ax.set_xlabel('Round time (s)', rotation=0, labelpad=10)
ax.set_ylabel('Win probability (%)', rotation=90, labelpad=20)
ax.grid(b=True, which="major", color="orange", linestyle="-", zorder=0, linewidth=.1, alpha=0.5)

formatter = mpl_ticker.FuncFormatter(lambda ms, x: time.strftime('%M:%S', time.gmtime(ms // 1000)))
ax.xaxis.set_major_formatter(formatter)

# ax.xaxis.labelpad = 10
# ax.yaxis.labelpad = 12
plt.title(f"{title_dict[chosen_side]} win probability over time")



# ax.lines[0].set_marker("o")
# ax.lines[0].set_markersize(9)

x_data = gp.plot_data["Round time"]
y_data = gp.plot_data["Win_probability"]
color_data = gp.plot_data["Colors"]
for round_time, win_probability, color in zip(x_data, y_data, color_data):
    if color is not None:
        ax.scatter(x=round_time, y=win_probability, color=color, edgecolor="w", marker="o", s=70, label="A")

plt.legend(framealpha=1, frameon=True)
#plt.axhline(y=9, color="black")
plt.show()

# %%
gp.kills_data_df
# Out:
#    round_number  timing  author  victim  event damage_type  weapon_id  \
# 0             3       0       0       0  start           0          0
# 1             3    8299  Delz1k  Nivera   kill      weapon         18
# 2             3   42780  Jamppi  keznit   kill      weapon          4
# 3             3   44737  Jamppi   Klaus   kill      weapon          4
# 4             3   56215  Jamppi  Delz1k   kill      weapon          4
# 5             3   63842    L1NK       0  plant           0          0
# 6             3   64286  Jamppi  Mazino   kill      weapon          4
# 7             3   92686  ScreaM    NagZ   kill      weapon          4
#
#    ability  probability_before  probability_after  ...  round_id  bomb_id  \
# 0        0            0.430148           0.430148  ...    939189        0
# 1        0            0.398597           0.299104  ...    939189        0
# 2        0            0.299104           0.179780  ...    939189        0
# 3        0            0.179780           0.247743  ...    939189        0
# 4        0            0.247743           0.469676  ...    939189        0
# 5        0            0.469676           0.236339  ...    939189   740159
# 6        0            0.236339           0.057067  ...    939189        0
# 7        0            0.049887           0.000000  ...    939189        0
#
#    res_id  event_id  author_agent  victim_agent weapon_name RoundTime stamp  \
# 0       0         0             0             0           0         0     A
# 1       0   7871670     Brimstone       Chamber     Spectre         8     B
# 2       0   7871666        Breach          Jett      Vandal        43     C
# 3       0   7871667        Breach        Breach      Vandal        45     D
# 4       0   7871668        Breach     Brimstone      Vandal        56     E
# 5       0    740159     Brimstone             0           0        64     F
# 6       0   7871669        Breach          Sage      Vandal        64     G
# 7       0   7871665          Jett       Chamber      Vandal        93     H
#
#     color
# 0   green
# 1  yellow
# 2  yellow
# 3  yellow
# 4  yellow
# 5  purple
# 6  yellow
# 7  yellow
#
# [8 rows x 22 columns]

# %%
gp.details_dict
# Out:
# {'Round_1': [{'round_number': 1,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 1,
#    'timing': 21510,
#    'author': 'keznit',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 12,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871652,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871652,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Ghost'},
#   {'round_number': 1,
#    'timing': 25623,
#    'author': 'keznit',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 12,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871653,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871653,
#    'author_agent': 'Jett',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Ghost'},
#   {'round_number': 1,
#    'timing': 26185,
#    'author': 'Nivera',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'headhunter',
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871657,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871657,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Chamber'},
#   {'round_number': 1,
#    'timing': 27177,
#    'author': 'Jamppi',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 11,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871656,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871656,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Classic'},
#   {'round_number': 1,
#    'timing': 28062,
#    'author': 'Mazino',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 11,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871654,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871654,
#    'author_agent': 'Sage',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Classic'},
#   {'round_number': 1,
#    'timing': 32816,
#    'author': 'Delz1k',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 10,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871658,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871658,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Frenzy'},
#   {'round_number': 1,
#    'timing': 70532,
#    'author': 'Mazino',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 11,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871655,
#    'round_id': 939187,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871655,
#    'author_agent': 'Sage',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Classic'}],
#  'Round_2': [{'round_number': 2,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 2,
#    'timing': 19526,
#    'author': 'keznit',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 17,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871659,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871659,
#    'author_agent': 'Jett',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Marshal'},
#   {'round_number': 2,
#    'timing': 26712,
#    'author': 'ScreaM',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871660,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871660,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Sheriff'},
#   {'round_number': 2,
#    'timing': 83677,
#    'author': 'NagZ',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871661,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871661,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Spectre'},
#   {'round_number': 2,
#    'timing': 87741,
#    'author': 'Delz1k',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871663,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871663,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Spectre'},
#   {'round_number': 2,
#    'timing': 87945,
#    'author': 'NagZ',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871662,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871662,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Spectre'},
#   {'round_number': 2,
#    'timing': 88980,
#    'author': 'Delz1k',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871664,
#    'round_id': 939188,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871664,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Spectre'}],
#  'Round_3': [{'round_number': 3,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 3,
#    'timing': 8299,
#    'author': 'Delz1k',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871670,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871670,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Spectre'},
#   {'round_number': 3,
#    'timing': 42780,
#    'author': 'Jamppi',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871666,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871666,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 3,
#    'timing': 44737,
#    'author': 'Jamppi',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871667,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871667,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 3,
#    'timing': 56215,
#    'author': 'Jamppi',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871668,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871668,
#    'author_agent': 'Breach',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'},
#   {'round_number': 3,
#    'timing': 63842,
#    'author': 'L1NK',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': None,
#    'round_id': 939189,
#    'bomb_id': 740159,
#    'res_id': None,
#    'event_id': 740159,
#    'author_agent': 'Brimstone'},
#   {'round_number': 3,
#    'timing': 64286,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871669,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871669,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Vandal'},
#   {'round_number': 3,
#    'timing': 92686,
#    'author': 'ScreaM',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871665,
#    'round_id': 939189,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871665,
#    'author_agent': 'Jett',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'}],
#  'Round_4': [{'round_number': 4,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 4,
#    'timing': 2974,
#    'author': 'keznit',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871672,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871672,
#    'author_agent': 'Jett',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Operator'},
#   {'round_number': 4,
#    'timing': 35342,
#    'author': 'Jamppi',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': None,
#    'round_id': 939190,
#    'bomb_id': 740160,
#    'res_id': None,
#    'event_id': 740160,
#    'author_agent': 'Breach'},
#   {'round_number': 4,
#    'timing': 36231,
#    'author': 'keznit',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'bladestorm',
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871673,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871673,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett'},
#   {'round_number': 4,
#    'timing': 41451,
#    'author': 'Klaus',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871674,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871674,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 4,
#    'timing': 41927,
#    'author': 'L1NK',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871671,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871671,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Vandal'},
#   {'round_number': 4,
#    'timing': 47082,
#    'author': 'Delz1k',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871675,
#    'round_id': 939190,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871675,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Vandal'},
#   {'round_number': 4,
#    'timing': 60119,
#    'author': 'Klaus',
#    'victim': None,
#    'event': 'defuse',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': None,
#    'round_id': 939190,
#    'bomb_id': 740160,
#    'res_id': None,
#    'event_id': 740160,
#    'author_agent': 'Breach'}],
#  'Round_5': [{'round_number': 5,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 5,
#    'timing': 7385,
#    'author': 'L1NK',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871676,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871676,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'},
#   {'round_number': 5,
#    'timing': 26696,
#    'author': 'L1NK',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': None,
#    'round_id': 939191,
#    'bomb_id': 740161,
#    'res_id': None,
#    'event_id': 740161,
#    'author_agent': 'Brimstone'},
#   {'round_number': 5,
#    'timing': 31741,
#    'author': 'Mazino',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871679,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871679,
#    'author_agent': 'Sage',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Vandal'},
#   {'round_number': 5,
#    'timing': 32694,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871680,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871680,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Phantom'},
#   {'round_number': 5,
#    'timing': 33971,
#    'author': 'Jamppi',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871681,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871681,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Phantom'},
#   {'round_number': 5,
#    'timing': 41065,
#    'author': 'ScreaM',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871677,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871677,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 5,
#    'timing': 42528,
#    'author': 'ScreaM',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871678,
#    'round_id': 939191,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871678,
#    'author_agent': 'Jett',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'}],
#  'Round_6': [{'round_number': 6,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939192,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 6,
#    'timing': 1572,
#    'author': 'Nivera',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871683,
#    'round_id': 939192,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871683,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Vandal'},
#   {'round_number': 6,
#    'timing': 9843,
#    'author': 'ScreaM',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871682,
#    'round_id': 939192,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871682,
#    'author_agent': 'Jett',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Phantom'},
#   {'round_number': 6,
#    'timing': 27901,
#    'author': 'Jamppi',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': None,
#    'round_id': 939192,
#    'bomb_id': 740162,
#    'res_id': None,
#    'event_id': 740162,
#    'author_agent': 'Breach'}],
#  'Round_7': [{'round_number': 7,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 7,
#    'timing': 10376,
#    'author': 'soulcas',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871689,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871689,
#    'author_agent': 'Neon',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'},
#   {'round_number': 7,
#    'timing': 23308,
#    'author': 'Delz1k',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871691,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871691,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Sheriff'},
#   {'round_number': 7,
#    'timing': 31562,
#    'author': 'L1NK',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': None,
#    'round_id': 939193,
#    'bomb_id': 740163,
#    'res_id': None,
#    'event_id': 740163,
#    'author_agent': 'Brimstone'},
#   {'round_number': 7,
#    'timing': 46589,
#    'author': 'Klaus',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871690,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871690,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Sheriff'},
#   {'round_number': 7,
#    'timing': 66496,
#    'author': 'Jamppi',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871685,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871685,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Phantom'},
#   {'round_number': 7,
#    'timing': 66892,
#    'author': 'Nivera',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871687,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871687,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'},
#   {'round_number': 7,
#    'timing': 68303,
#    'author': 'Nivera',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871688,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871688,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 7,
#    'timing': 69172,
#    'author': 'Mazino',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871684,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871684,
#    'author_agent': 'Sage',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Sheriff'},
#   {'round_number': 7,
#    'timing': 69740,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.007868606640067902,
#    'probability_after': 0.007868606640067902,
#    'impact': 0.0,
#    'kill_id': 7871686,
#    'round_id': 939193,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871686,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Phantom'}],
#  'Round_8': [{'round_number': 8,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 8,
#    'timing': 13178,
#    'author': 'NagZ',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871695,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871695,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 8,
#    'timing': 14386,
#    'author': 'NagZ',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871696,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871696,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Vandal'},
#   {'round_number': 8,
#    'timing': 17050,
#    'author': 'Klaus',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871698,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871698,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 8,
#    'timing': 18534,
#    'author': 'Nivera',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'tour-de-force',
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871697,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871697,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Chamber'},
#   {'round_number': 8,
#    'timing': 18936,
#    'author': 'L1NK',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871692,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871692,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 8,
#    'timing': 20668,
#    'author': 'keznit',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871693,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871693,
#    'author_agent': 'Jett',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'},
#   {'round_number': 8,
#    'timing': 24199,
#    'author': 'keznit',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871694,
#    'round_id': 939194,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871694,
#    'author_agent': 'Jett',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'}],
#  'Round_9': [{'round_number': 9,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 9,
#    'timing': 74882,
#    'author': 'soulcas',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871704,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871704,
#    'author_agent': 'Neon',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Phantom'},
#   {'round_number': 9,
#    'timing': 83859,
#    'author': 'L1NK',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871699,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871699,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 9,
#    'timing': 84264,
#    'author': 'Mazino',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871701,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871701,
#    'author_agent': 'Sage',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Phantom'},
#   {'round_number': 9,
#    'timing': 84904,
#    'author': 'ScreaM',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871700,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871700,
#    'author_agent': 'Jett',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 9,
#    'timing': 85110,
#    'author': 'Delz1k',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871705,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871705,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 9,
#    'timing': 90506,
#    'author': 'Mazino',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871702,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871702,
#    'author_agent': 'Sage',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Phantom'},
#   {'round_number': 9,
#    'timing': 91677,
#    'author': 'Mazino',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871703,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871703,
#    'author_agent': 'Sage',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Phantom'},
#   {'round_number': 9,
#    'timing': 93235,
#    'author': 'Delz1k',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871706,
#    'round_id': 939195,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871706,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'}],
#  'Round_10': [{'round_number': 10,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 10,
#    'timing': 28624,
#    'author': 'L1NK',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871707,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871707,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 10,
#    'timing': 30637,
#    'author': 'Klaus',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871712,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871712,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 10,
#    'timing': 32389,
#    'author': 'soulcas',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'overdrive',
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871709,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871709,
#    'author_agent': 'Neon',
#    'victim_agent': 'Chamber'},
#   {'round_number': 10,
#    'timing': 40465,
#    'author': 'Klaus',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871713,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871713,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 10,
#    'timing': 41085,
#    'author': 'soulcas',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'overdrive',
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871710,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871710,
#    'author_agent': 'Neon',
#    'victim_agent': 'Breach'},
#   {'round_number': 10,
#    'timing': 42185,
#    'author': 'soulcas',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'overdrive',
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871711,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871711,
#    'author_agent': 'Neon',
#    'victim_agent': 'Sage'},
#   {'round_number': 10,
#    'timing': 49934,
#    'author': 'L1NK',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871708,
#    'round_id': 939196,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871708,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'},
#   {'round_number': 10,
#    'timing': 54742,
#    'author': 'L1NK',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939196,
#    'bomb_id': 740164,
#    'res_id': None,
#    'event_id': 740164,
#    'author_agent': 'Brimstone'}],
#  'Round_11': [{'round_number': 11,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 11,
#    'timing': 7556,
#    'author': 'Delz1k',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871722,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871722,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 31473,
#    'author': 'ScreaM',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'bladestorm',
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871718,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871718,
#    'author_agent': 'Jett',
#    'victim_agent': 'Brimstone'},
#   {'round_number': 11,
#    'timing': 41093,
#    'author': 'keznit',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871717,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871717,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 41916,
#    'author': 'Mazino',
#    'victim': 'Delz1k',
#    'event': 'revival',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': None,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': 64933,
#    'event_id': 64933,
#    'author_agent': 'Sage',
#    'victim_agent': 'Brimstone'},
#   {'round_number': 11,
#    'timing': 42738,
#    'author': 'soulcas',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871720,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871720,
#    'author_agent': 'Neon',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 51572,
#    'author': 'L1NK',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': None,
#    'round_id': 939197,
#    'bomb_id': 740165,
#    'res_id': None,
#    'event_id': 740165,
#    'author_agent': 'Brimstone'},
#   {'round_number': 11,
#    'timing': 54667,
#    'author': 'L1NK',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871714,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871714,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 55937,
#    'author': 'L1NK',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871715,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871715,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 57065,
#    'author': 'L1NK',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.007868606640067902,
#    'probability_after': 0.007868606640067902,
#    'impact': 0.0,
#    'kill_id': 7871716,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871716,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 61681,
#    'author': 'NagZ',
#    'victim': 'Nivera',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.008088430640977803,
#    'probability_after': 0.008088430640977803,
#    'impact': 0.0,
#    'kill_id': 7871719,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871719,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'},
#   {'round_number': 11,
#    'timing': 73309,
#    'author': 'soulcas',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.0055540365412575935,
#    'probability_after': 0.0055540365412575935,
#    'impact': 0.0,
#    'kill_id': 7871721,
#    'round_id': 939197,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871721,
#    'author_agent': 'Neon',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'}],
#  'Round_12': [{'round_number': 12,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 12,
#    'timing': 20479,
#    'author': 'Nivera',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871726,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871726,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Operator'},
#   {'round_number': 12,
#    'timing': 27202,
#    'author': 'Jamppi',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871724,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871724,
#    'author_agent': 'Breach',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Vandal'},
#   {'round_number': 12,
#    'timing': 28642,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871725,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871725,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Vandal'},
#   {'round_number': 12,
#    'timing': 30307,
#    'author': 'Nivera',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871727,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871727,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Operator'},
#   {'round_number': 12,
#    'timing': 30545,
#    'author': 'Klaus',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871728,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871728,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Spectre'},
#   {'round_number': 12,
#    'timing': 30949,
#    'author': 'ScreaM',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871723,
#    'round_id': 939198,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871723,
#    'author_agent': 'Jett',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Phantom'}],
#  'Round_13': [{'round_number': 13,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939199,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 13,
#    'timing': 21632,
#    'author': 'Nivera',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 14,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871733,
#    'round_id': 939199,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871733,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Shorty'},
#   {'round_number': 13,
#    'timing': 27279,
#    'author': 'Klaus',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': None,
#    'round_id': 939199,
#    'bomb_id': 740166,
#    'res_id': None,
#    'event_id': 740166,
#    'author_agent': 'Breach'},
#   {'round_number': 13,
#    'timing': 36451,
#    'author': 'ScreaM',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871729,
#    'round_id': 939199,
#    'bomb_id': None,
# ...
#    'damage_type': 'weapon',
#    'weapon_id': 5,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871742,
#    'round_id': 939201,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871742,
#    'author_agent': 'Jett',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Bulldog'},
#   {'round_number': 15,
#    'timing': 32054,
#    'author': 'soulcas',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871746,
#    'round_id': 939201,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871746,
#    'author_agent': 'Neon',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Spectre'},
#   {'round_number': 15,
#    'timing': 37067,
#    'author': 'Nivera',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 11,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871745,
#    'round_id': 939201,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871745,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Classic'}],
#  'Round_16': [{'round_number': 16,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 16,
#    'timing': 47875,
#    'author': 'ScreaM',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 5,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871749,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871749,
#    'author_agent': 'Jett',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Bulldog'},
#   {'round_number': 16,
#    'timing': 56314,
#    'author': 'L1NK',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871747,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871747,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Spectre'},
#   {'round_number': 16,
#    'timing': 57906,
#    'author': 'Delz1k',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': None,
#    'round_id': 939202,
#    'bomb_id': 740168,
#    'res_id': None,
#    'event_id': 740168,
#    'author_agent': 'Brimstone'},
#   {'round_number': 16,
#    'timing': 75449,
#    'author': 'L1NK',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871748,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871748,
#    'author_agent': 'Brimstone',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Spectre'},
#   {'round_number': 16,
#    'timing': 75938,
#    'author': 'Klaus',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871753,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871753,
#    'author_agent': 'Breach',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Vandal'},
#   {'round_number': 16,
#    'timing': 76756,
#    'author': 'Klaus',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871754,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871754,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 16,
#    'timing': 77786,
#    'author': 'soulcas',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871752,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871752,
#    'author_agent': 'Neon',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Spectre'},
#   {'round_number': 16,
#    'timing': 78884,
#    'author': 'Mazino',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871750,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871750,
#    'author_agent': 'Sage',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Phantom'},
#   {'round_number': 16,
#    'timing': 79237,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.007868606640067902,
#    'probability_after': 0.007868606640067902,
#    'impact': 0.0,
#    'kill_id': 7871751,
#    'round_id': 939202,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871751,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Phantom'},
#   {'round_number': 16,
#    'timing': 95443,
#    'author': 'Nivera',
#    'victim': None,
#    'event': 'defuse',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.008088430640977803,
#    'probability_after': 0.008088430640977803,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939202,
#    'bomb_id': 740168,
#    'res_id': None,
#    'event_id': 740168,
#    'author_agent': 'Chamber'}],
#  'Round_17': [{'round_number': 17,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 17,
#    'timing': 5374,
#    'author': 'soulcas',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871760,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871760,
#    'author_agent': 'Neon',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Phantom'},
#   {'round_number': 17,
#    'timing': 15915,
#    'author': 'soulcas',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': 7871761,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871761,
#    'author_agent': 'Neon',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Phantom'},
#   {'round_number': 17,
#    'timing': 17270,
#    'author': 'soulcas',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871762,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871762,
#    'author_agent': 'Neon',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Phantom'},
#   {'round_number': 17,
#    'timing': 17721,
#    'author': 'NagZ',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'headhunter',
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871755,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871755,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Neon'},
#   {'round_number': 17,
#    'timing': 24748,
#    'author': 'Jamppi',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871758,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871758,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Phantom'},
#   {'round_number': 17,
#    'timing': 26243,
#    'author': 'NagZ',
#    'victim': 'Jamppi',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'headhunter',
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871756,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871756,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Breach'},
#   {'round_number': 17,
#    'timing': 47295,
#    'author': 'NagZ',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 18,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871757,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871757,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Spectre'},
#   {'round_number': 17,
#    'timing': 47930,
#    'author': 'Nivera',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 13,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871759,
#    'round_id': 939203,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871759,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Sheriff'}],
#  'Round_18': [{'round_number': 18,
#    'timing': 0,
#    'author': None,
#    'victim': None,
#    'event': 'start',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.4301476383265247,
#    'probability_after': 0.4301476383265247,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': None},
#   {'round_number': 18,
#    'timing': 23325,
#    'author': 'Jamppi',
#    'victim': 'Delz1k',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.3985974091534485,
#    'probability_after': 0.299103948553757,
#    'impact': 0.0994934605996915,
#    'kill_id': 7871765,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871765,
#    'author_agent': 'Breach',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Operator'},
#   {'round_number': 18,
#    'timing': 35763,
#    'author': 'Mazino',
#    'victim': None,
#    'event': 'plant',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.299103948553757,
#    'probability_after': 0.17978015496337688,
#    'impact': 0.11932379359038012,
#    'kill_id': None,
#    'round_id': 939204,
#    'bomb_id': 740169,
#    'res_id': None,
#    'event_id': 740169,
#    'author_agent': 'Sage'},
#   {'round_number': 18,
#    'timing': 59996,
#    'author': 'Nivera',
#    'victim': 'NagZ',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.17978015496337688,
#    'probability_after': 0.24774332787279305,
#    'impact': 0.06796317290941617,
#    'kill_id': 7871768,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871768,
#    'author_agent': 'Chamber',
#    'victim_agent': 'Chamber',
#    'weapon_name': 'Operator'},
#   {'round_number': 18,
#    'timing': 62040,
#    'author': 'Klaus',
#    'victim': 'ScreaM',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 4,
#    'ability': None,
#    'probability_before': 0.24774332787279305,
#    'probability_after': 0.4696763238555302,
#    'impact': 0.22193299598273716,
#    'kill_id': 7871770,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871770,
#    'author_agent': 'Breach',
#    'victim_agent': 'Jett',
#    'weapon_name': 'Vandal'},
#   {'round_number': 18,
#    'timing': 62058,
#    'author': 'Jamppi',
#    'victim': 'Klaus',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 15,
#    'ability': None,
#    'probability_before': 0.4696763238555302,
#    'probability_after': 0.23633886560087983,
#    'impact': 0.23333745825465038,
#    'kill_id': 7871766,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871766,
#    'author_agent': 'Breach',
#    'victim_agent': 'Breach',
#    'weapon_name': 'Operator'},
#   {'round_number': 18,
#    'timing': 62270,
#    'author': 'soulcas',
#    'victim': 'keznit',
#    'event': 'kill',
#    'damage_type': 'ability',
#    'weapon_id': None,
#    'ability': 'overdrive',
#    'probability_before': 0.23633886560087983,
#    'probability_after': 0.05706714510557386,
#    'impact': 0.17927172049530596,
#    'kill_id': 7871769,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871769,
#    'author_agent': 'Neon',
#    'victim_agent': 'Jett'},
#   {'round_number': 18,
#    'timing': 63060,
#    'author': 'Mazino',
#    'victim': 'soulcas',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.04988660007289539,
#    'probability_after': 0.0,
#    'impact': 0.04988660007289539,
#    'kill_id': 7871763,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871763,
#    'author_agent': 'Sage',
#    'victim_agent': 'Neon',
#    'weapon_name': 'Phantom'},
#   {'round_number': 18,
#    'timing': 65890,
#    'author': 'Mazino',
#    'victim': 'L1NK',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 6,
#    'ability': None,
#    'probability_before': 0.011951263123387663,
#    'probability_after': 0.011951263123387663,
#    'impact': 0.0,
#    'kill_id': 7871764,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871764,
#    'author_agent': 'Sage',
#    'victim_agent': 'Brimstone',
#    'weapon_name': 'Phantom'},
#   {'round_number': 18,
#    'timing': 66695,
#    'author': 'Jamppi',
#    'victim': 'Mazino',
#    'event': 'kill',
#    'damage_type': 'weapon',
#    'weapon_id': 10,
#    'ability': None,
#    'probability_before': 0.007868606640067902,
#    'probability_after': 0.007868606640067902,
#    'impact': 0.0,
#    'kill_id': 7871767,
#    'round_id': 939204,
#    'bomb_id': None,
#    'res_id': None,
#    'event_id': 7871767,
#    'author_agent': 'Breach',
#    'victim_agent': 'Sage',
#    'weapon_name': 'Frenzy'},
#   {'round_number': 18,
#    'timing': 75398,
#    'author': 'Jamppi',
#    'victim': None,
#    'event': 'defuse',
#    'damage_type': None,
#    'weapon_id': None,
#    'ability': None,
#    'probability_before': 0.008088430640977803,
#    'probability_after': 0.008088430640977803,
#    'impact': 0.0,
#    'kill_id': None,
#    'round_id': 939204,
#    'bomb_id': 740169,
#    'res_id': None,
#    'event_id': 740169,
#    'author_agent': 'Breach'}]}
