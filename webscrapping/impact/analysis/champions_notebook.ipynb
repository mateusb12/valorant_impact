# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("champions_analysis.csv")
df
# Out:
#     Ranking       Name  Gain_sum  Lost_sum  Delta_sum (%)  Matches  Per match  \
# 0         1      d3ffo   4323.54   3456.60         866.94       17      51.00
# 1         2  Chronicle   4185.94   3383.58         802.36       17      47.20
# 2        37     keznit   3946.51   3943.50           3.01       14       0.21
# 3        12       nAts   3684.64   3236.30         448.33       17      26.37
# 4        72    sheydos   3667.80   3953.35        -285.55       17     -16.80
# ..      ...        ...       ...       ...            ...      ...        ...
# 77       62       JhoW    598.90    789.06        -190.16        4     -47.54
# 78       25      Bazzi    578.43    416.94         161.49        2      80.75
# 79       65        ade    520.96    735.07        -214.10        4     -53.53
# 80       41     Medusa    454.74    461.55          -6.81        2      -3.41
# 81       49      Lakia    193.51    256.12         -62.61        1     -62.61
#
#     ACS   KDA Fav Rifle             Team  Kills  Deaths  Assists
# 0   227  1.08    Vandal   Gambit Esports    275     254       59
# 1   238  1.30    Vandal   Gambit Esports    297     229       81
# 2   246  1.15   Phantom      KRÜ Esports    272     236       69
# 3   211  1.17   Phantom   Gambit Esports    266     228       95
# 4   189  0.96    Vandal   Gambit Esports    240     249       82
# ..  ...   ...       ...              ...    ...     ...      ...
# 77  152  0.63   Phantom        Vivo Keyd     46      73       25
# 78  207  0.90    Vandal    Crazy Raccoon     28      31       14
# 79  104  0.46    Vandal    Crazy Raccoon     29      63       25
# 80  203  0.75   Phantom    Crazy Raccoon     24      32        7
# 81  203  0.94   Phantom  Vision Strikers     15      16        3
#
# [82 rows x 14 columns]

# %%
# Change the figsize
plt.figure(figsize=(10,6))
x_axis = "Fav Rifle"
y_axis = "Delta_sum (%)"
ax = sns.violinplot(x=x_axis, y=y_axis, data=df)
sns.stripplot(x=x_axis, y=y_axis, data=df,
              color="maroon", edgecolor="gray")

ax.set_xlabel("Favorite Rifle",fontsize=15)
ax.set_ylabel("Player Delta Impact",fontsize=15)
# Out:
# Text(0, 0.5, 'Player Delta Impact')

# %%
plt.figure(figsize=(24,6))
# Apply the lambda function x: x.split[" "][-1] on df["Team"]
df["Team"].unique()
team_trim = {"Gambit Esports": "Gambit",
             "KRÜ Esports": "KRU",
             "Cloud9 Blue": "C9",
             "Acend": "Acend",
             "Fnatic": "Fnatic",
             "Sentinels": "Sentinels",
             "Team Liquid": "Liquid",
             "X10 CRIT (ex)": "X10",
             "X10 CRIT": "X10",
             "Fnatic (ex)": "FNATIC",
             "Team Secret": "Secret",
             "Team Envy": "Envy",
             "Vision Strikers": "VS",
             "Team Vikings": "Vikings",
             "Team Vikings (ex)": "Vikings",
             "FURIA Esports": "FURIA",
             "Vivo Keyd": "VK",
             "FULL SENSE": "FS",
             "Crazy Raccoon": "CR",
             "Crazy Raccoon (ex)": "CR"}
df_copy = df.copy()
df_copy["Team"] = df_copy["Team"].map(team_trim)
df_group = df_copy.groupby(["Team"]).sum().reset_index()
sns.barplot(x=df_group["Team"], y=df_group["Gain_sum"], edgecolor="black")
#df_group
# Out:
# <AxesSubplot:xlabel='Team', ylabel='Gain_sum'>

# %%
# sort df by Delta-sum (%) ascending
df.sort_values(by=["Delta_sum (%)"], ascending=True)
# Out:
#     Ranking       Name  Gain_sum  Lost_sum  Delta_sum (%)  Matches  Per match  \
# 13       82     Delz1k   2859.06   3586.95        -727.89       14     -51.99
# 64       81     Victor   1080.38   1723.11        -642.73        7     -91.82
# 8        80     Mazino   3176.09   3781.45        -605.35       14     -43.24
# 29       79     Xeppaa   2104.17   2658.76        -554.60       10     -55.46
# 31       78      kiles   2017.79   2512.57        -494.78       13     -38.06
# ..      ...        ...       ...       ...            ...      ...        ...
# 38        5   crashies   1946.27   1345.57         600.70        7      85.81
# 6         4       leaf   3278.12   2671.43         606.69       10      60.67
# 12        3      Derke   2920.39   2207.67         712.72        9      79.19
# 1         2  Chronicle   4185.94   3383.58         802.36       17      47.20
# 0         1      d3ffo   4323.54   3456.60         866.94       17      51.00
#
#     ACS   KDA Fav Rifle            Team  Kills  Deaths  Assists
# 13  167  0.80   Phantom     KRÜ Esports    185     230       89
# 64  162  0.81   Phantom       Team Envy     91     112       50
# 8   211  1.00    Vandal     KRÜ Esports    226     226       92
# 29  195  0.89   Phantom     Cloud9 Blue    154     174       77
# 31  155  0.85   Phantom           Acend    165     194       77
# ..  ...   ...       ...             ...    ...     ...      ...
# 38  209  1.22    Vandal       Team Envy    117      96       51
# 6   260  1.19    Vandal     Cloud9 Blue    210     176       58
# 12  277  1.38    Vandal          Fnatic    201     146       34
# 1   238  1.30    Vandal  Gambit Esports    297     229       81
# 0   227  1.08    Vandal  Gambit Esports    275     254       59
#
# [82 rows x 14 columns]
