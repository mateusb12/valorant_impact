# %%
from webscrapping.model.lgbm_model import ValorantLGBM
from match_analysis import RoundReplay, train_model

rr = RoundReplay()
rr.set_match(43612)
# Out:
# Analyser created!
# [LightGBM] [Warning] min_data_in_leaf is set=99, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=99
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=3, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=3
# [LightGBM] [Warning] num_threads is set=4, n_jobs=-1 will be ignored. Current value: num_threads=4
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
rr.choose_round(8)

# %%
rr.plot_round(side="def")

# %%
rr.get_round_probability(side="def", add_events=True)
# Out:
#     Round  Round time Stamps  Difference (%)     Actors         Means  \
# 0       8        0.00      A            0.00       None          None
# 1       8        7.00      B           16.92        FNS       Phantom
# 2       8        7.30      C          -22.90     sScary        Vandal
# 3       8        7.56      D           34.68        yay      Operator
# 4       8       87.52      E          -29.46   Patiphan       Phantom
# 5       8       92.69      F           -2.11  sushiboys         spike
# 6       8       93.70      G          -32.63       foxz        Vandal
# 7       8       95.24      H           18.07   crashies  hunters-fury
# 8       8       98.04      I           46.58   crashies        Vandal
# 9       8      101.49      J           19.88   crashies        Vandal
# 10      8      121.24      K           -0.16   crashies         spike
#
#       Victims  Win_probability Final Winner
# 0        None            49.77          def
# 1        crws            66.69          def
# 2         FNS            43.79          def
# 3      sScary            78.47          def
# 4      Marved            49.01          def
# 5       spike            46.90          def
# 6         yay            14.27          def
# 7   sushiboys            32.34          def
# 8        foxz            78.92          def
# 9    Patiphan            98.80          def
# 10      spike            98.64          def

# %%
rr.get_player_most_impactful_rounds("crashies")
# Out:
#         Name  RoundNumber  gained   lost  delta
# 0   crashies            8   84.53   0.00  84.53
# 1   crashies           18   50.24   0.00  50.24
# 2   crashies           20   38.62   0.00  38.62
# 3   crashies            7   22.44   0.00  22.44
# 4   crashies            4   20.53   3.64  16.89
# 5   crashies           15   15.84   0.00  15.84
# 6   crashies            5   12.03   0.68  11.35
# 7   crashies           21    5.81   0.00   5.81
# 8   crashies           14    3.03   1.54   1.49
# 9   crashies            6    0.00   0.00   0.00
# 10  crashies           16    0.00   0.00   0.00
# 11  crashies            2    0.00   1.11  -1.11
# 12  crashies            3    0.16   3.12  -2.96
# 13  crashies            1    0.46   4.54  -4.08
# 14  crashies            9    0.00   4.96  -4.96
# 15  crashies           12    0.00  11.77 -11.77
# 16  crashies           10    5.48  20.37 -14.89
# 17  crashies           19    0.00  22.16 -22.16
# 18  crashies           13    0.00  24.83 -24.83
# 19  crashies           11    0.00  27.62 -27.62
# 20  crashies           17    0.00  27.67 -27.67

# %%
rr.get_map_impact_dataframe()
# Out:
#         Name    Gain    Lost   Delta  MatchID
# 0   Bonecold  233.60  110.65  122.95    45334
# 1    sheydos  259.57  189.56   70.01    45334
# 2     Redgar  186.98  161.82   25.16    45334
# 3      d3ffo  154.22  143.52   10.70    45334
# 4       zeek  168.16  168.85   -0.69    45334
# 5       cNed  154.20  156.52   -2.32    45334
# 6      kiles  123.07  132.08   -9.01    45334
# 7     Starxo  126.13  185.08  -58.95    45334
# 8       nAts  106.13  177.19  -71.06    45334
# 9  Chronicle   46.28  133.07  -86.79    45334
