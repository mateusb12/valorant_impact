# %%
from webscrapping.model.lgbm_model import ValorantLGBM
from match_analysis import RoundReplay, train_model

rr = RoundReplay()
rr.set_match(44866)
# Out:
# Analyser created!
# [LightGBM] [Warning] min_data_in_leaf is set=99, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=99
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=3, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=3
# [LightGBM] [Warning] num_threads is set=4, n_jobs=-1 will be ignored. Current value: num_threads=4
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
rr.choose_round(8)

# %%
rr.plot_round(side="def")

# %%
rr.get_round_probability(side="def", add_events=True)
# Out:
#    Round  Round time Stamps  Difference (%)  Actors     Means Victims  \
# 0      8        0.00      A            0.00    None      None    None
# 1      8        1.95      B           10.35  Xeppaa  fragment    BuZz
# 2      8       55.78      C            9.52    xeta      Odin      Rb
# 3      8       56.75      D            5.18    leaf  Operator    k1Ng
# 4      8       58.83      E           -1.37    stax   Spectre    xeta
# 5      8       64.34      F            1.69  Xeppaa   Phantom    stax
# 6      8       76.56      G            0.29  Xeppaa   Phantom    MaKo
#
#    Win_probability Final Winner
# 0            73.94          def
# 1            84.29          def
# 2            93.81          def
# 3            98.99          def
# 4            97.62          def
# 5            99.31          def
# 6            99.60          def

# %%
rr.get_player_most_impactful_rounds("leaf")
# Out:
#     Name  RoundNumber  gained   lost  delta
# 0   leaf            7   52.62   0.00  52.62
# 1   leaf           15   56.04  12.52  43.52
# 2   leaf            3   44.43   6.32  38.11
# 3   leaf           19   52.62  15.50  37.12
# 4   leaf            5   35.97   0.00  35.97
# 5   leaf            1   21.88   0.00  21.88
# 6   leaf           10   17.14   0.00  17.14
# 7   leaf            4   19.44   3.22  16.22
# 8   leaf           12   15.39   1.17  14.22
# 9   leaf           14   22.01  11.24  10.77
# 10  leaf           18   11.12   3.64   7.48
# 11  leaf           23   25.51  19.56   5.95
# 12  leaf            8    5.18   0.00   5.18
# 13  leaf            2    3.87   0.00   3.87
# 14  leaf           20   11.55   9.54   2.01
# 15  leaf           11    0.00   0.00   0.00
# 16  leaf           17    0.00   0.80  -0.80
# 17  leaf           13   65.75  67.87  -2.12
# 18  leaf            6    9.47  13.09  -3.62
# 19  leaf           22    0.00   7.19  -7.19
# 20  leaf            9    0.00  12.03 -12.03
# 21  leaf           16    0.00  17.94 -17.94
# 22  leaf           21    0.00  24.14 -24.14

# %%
rr.get_map_impact_dataframe()
# Out:
#         Name    Gain    Lost   Delta  MatchID
# 0   Bonecold  233.60  110.65  122.95    45334
# 1    sheydos  259.57  189.56   70.01    45334
# 2     Redgar  186.98  161.82   25.16    45334
# 3      d3ffo  154.22  143.52   10.70    45334
# 4       zeek  168.16  168.85   -0.69    45334
# 5       cNed  154.20  156.52   -2.32    45334
# 6      kiles  123.07  132.08   -9.01    45334
# 7     Starxo  126.13  185.08  -58.95    45334
# 8       nAts  106.13  177.19  -71.06    45334
# 9  Chronicle   46.28  133.07  -86.79    45334
